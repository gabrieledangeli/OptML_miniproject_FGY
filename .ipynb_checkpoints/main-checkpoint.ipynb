# %%
import numpy as np
from optimizers.optimizers_xy import *
from optimizers.optimizers_conv_conc import *
from optimizers.optimizers_conc_conv import *
from plot import *

# %% [markdown]
# ## SECTION 1

# %% [markdown]
# In this part, we propose three simple example of how changing the optimization algorithm change the convergence of the optimization problems $min_{x\in\mathbb{R^m}}f(x,y)$, $min_{y\in\mathbb{R^m}}g(x,y)$. Many problems in competitive optimization, including GANs, have the form $f(x,y)=\mathbb{\phi}(\mathcal{G}(x),\mathcal{D}(y))$, $f(x,y)=\mathbb{\theta}(\mathcal{G}(x),\mathcal{D}(y))$. We will explore different modification of Gradient Descent that take into account some additional terms. These new terms refers in some way to competition, consensus and equilibrium (we will describe them further in this section).

# %% [markdown]
# #### PROBLEM 1
# We firstly consider the problem $$min_{x\in\mathbb{R^m}}f(x,y)$$  $$min_{y\in\mathbb{R^m}}(-f(x,y))$$
# In this first case, we take $f(x,y)=xy$, so $\alpha=1$

# %%
alpha = 1

# %% [markdown]
# #### 1) Gradient Descent

# %%
initial_x = 0.5
initial_y = 0.5
max_iters = 50
eta = 0.2
objectives_GD, xs_GD, ys_GD = gradient_descent_xy(initial_x, initial_y, alpha, max_iters, eta)
# Out:
# Gradient Descent(0/49): objective=0.25
# Gradient Descent(1/49): objective=0.24
# Gradient Descent(2/49): objective=0.1904
# Gradient Descent(3/49): objective=0.10598400000000004
# Gradient Descent(4/49): objective=-0.002447359999999964
# Gradient Descent(5/49): objective=-0.11933122559999998
# Gradient Descent(6/49): objective=-0.226468888576
# Gradient Descent(7/49): objective=-0.30575161245696003
# Gradient Descent(8/49): objective=-0.3420943460335616
# Gradient Descent(9/49): objective=-0.3261202003509903
# Gradient Descent(10/49): objective=-0.2561415400040012
# Gradient Descent(11/49): objective=-0.13906014810805115
# Gradient Descent(12/49): objective=0.010047205300869477
# Gradient Descent(13/49): objective=0.1696980903713375
# Gradient Descent(14/49): objective=0.3149532762595476
# Gradient Descent(15/49): objective=0.42116483587269277
# Gradient Descent(16/49): objective=0.46798302127324337
# Gradient Descent(17/49): objective=0.4429955143647228
# Gradient Descent(18/49): objective=0.3443809517711277
# Gradient Descent(19/49): objective=0.18206747906368104
# Gradient Descent(20/49): objective=-0.022912877633384163
# Gradient Descent(21/49): objective=-0.24091691041137503
# Gradient Descent(22/49): objective=-0.43777789954157176
# Gradient Descent(23/49): objective=-0.5799578368188746
# Gradient Descent(24/49): objective=-0.6400184705480751
# Gradient Descent(25/49): objective=-0.6015530671490096
# Gradient Descent(26/49): objective=-0.46273791118130025
# Gradient Descent(27/49): objective=-0.23781699203972778
# Gradient Descent(28/49): objective=0.04388870001741707
# Gradient Descent(29/49): objective=0.3414891626236104
# Gradient Descent(30/49): objective=0.6081891742984936
# Gradient Descent(31/49): objective=0.7983685363594107
# Gradient Descent(32/49): objective=0.875050178888818
# Gradient Descent(33/49): objective=0.8165809345401916
# Gradient Descent(34/49): objective=0.6213811208310226
# Gradient Descent(35/49): objective=0.3098378131968921
# Gradient Descent(36/49): objective=-0.07719721895280111
# Gradient Descent(37/49): objective=-0.48333923914313665
# Gradient Descent(38/49): objective=-0.8445148271354725
# Gradient Descent(39/49): objective=-1.0986887470428908
# Gradient Descent(40/49): objective=-1.196055157292623
# Gradient Descent(41/49): objective=-1.1080841532002457
# Gradient Descent(42/49): objective=-0.8338683160167705
# Gradient Descent(43/49): objective=-0.4025233466508136
# Gradient Descent(44/49): objective=0.1290671450341769
# Gradient Descent(45/49): objective=0.6831781702031396
# Gradient Descent(46/49): objective=1.1721030627210622
# Gradient Descent(47/49): objective=1.5115123715327237
# Gradient Descent(48/49): objective=1.6343570807037284
# Gradient Descent(49/49): objective=1.5031138139013647

# %%
plt.figure()
plt.grid()
plt.plot(xs_GD, ys_GD, 'b--', linewidth=1, label="GD")
plt.ylabel("y")
plt.xlabel("x")
plt.title("Trajectory of GD")
plt.legend()
# Add markers for the starting and end points
plt.scatter(xs_GD[0], ys_GD[0], c='r', marker='o', label='Start')
plt.scatter(xs_GD[-1], ys_GD[-1], c='g', marker='o', label='End')
plt.legend()

plt.show()

# %% [markdown]
# It is clear that GD fail to converge in this problem.

# %% [markdown]
# #### 2) LCGD

# %% [markdown]
# Notice that LCGD is SG algorithm with gamma and eta equals.

# %%
initial_x = 0.5
initial_y = 0.5
max_iters = 50
gamma = 0.2
eta = 0.2
objectives_LCGD, xs_LCGD, ys_LCGD = SG_xy(initial_x, initial_y, alpha, max_iters, eta, gamma)
# Out:
# SG(0/49): objective=0.25
# SG(1/49): objective=0.15000000000000002
# SG(2/49): objective=0.06440000000000001
# SG(3/49): objective=0.007919999999999995
# SG(4/49): objective=-0.020274560000000018
# SG(5/49): objective=-0.02799168000000002
# SG(6/49): objective=-0.024215059456000013
# SG(7/49): objective=-0.016114718515200008
# SG(8/49): objective=-0.008140618725785604
# SG(9/49): objective=-0.002317296629514241
# SG(10/49): objective=0.0009834661433861744
# SG(11/49): objective=0.0022516773335507943
# SG(12/49): objective=0.0022472580555591855
# SG(13/49): objective=0.0016555340676371359
# SG(14/49): objective=0.0009475087562739957
# SG(15/49): objective=0.00037149155465338306
# SG(16/49): objective=7.66181668296409e-06
# SG(17/49): objective=-0.00016258351485216744
# SG(18/49): objective=-0.00019864304185680348
# SG(19/49): objective=-0.00016319303296052193
# SG(20/49): objective=-0.00010397909699804038
# SG(21/49): objective=-4.931445795670312e-05
# SG(22/49): objective=-1.1097415096149865e-05
# SG(23/49): objective=9.48610724379968e-06
# SG(24/49): objective=1.6514773433019312e-05
# SG(25/49): objective=1.54313521300902e-05
# SG(26/49): objective=1.0881191320680108e-05
# SG(27/49): objective=5.921972359862423e-06
# SG(28/49): objective=2.0749039651524254e-06
# SG(29/49): objective=-2.4843526101747395e-07
# SG(30/49): objective=-1.2575579067074504e-06
# SG(31/49): objective=-1.3941930233544606e-06
# SG(32/49): objective=-1.0915368519638274e-06
# SG(33/49): objective=-6.651693683574903e-07
# SG(34/49): objective=-2.934766016809146e-07
# SG(35/49): objective=-4.4597606088594e-08
# SG(36/49): objective=8.21864533109421e-08
# SG(37/49): objective=1.1924567702849636e-07
# SG(38/49): objective=1.0509179642321599e-07
# SG(39/49): objective=7.097095464988248e-08
# SG(40/49): objective=3.657069891376389e-08
# SG(41/49): objective=1.1067869266411011e-08
# SG(42/49): objective=-3.62884805803121e-09
# SG(43/49): objective=-9.472400418425904e-09
# SG(44/49): objective=-9.688901160077453e-09
# SG(45/49): objective=-7.246643438612804e-09
# SG(46/49): objective=-4.215824229915549e-09
# SG(47/49): objective=-1.708141149884099e-09
# SG(48/49): objective=-1.003722559479689e-10
# SG(49/49): objective=6.693977605688446e-10

# %%
plt.figure()
plt.grid()
plt.plot(xs_LCGD, ys_LCGD, 'b--', linewidth=1, label="LCGD")
plt.ylabel("y")
plt.xlabel("x")
plt.title("Trajectory of LCGD")
plt.legend()
# Add markers for the starting and end points
plt.scatter(xs_LCGD[0], ys_LCGD[0], c='r', marker='o', label='Start')
plt.scatter(xs_LCGD[-1], ys_LCGD[-1], c='g', marker='o', label='End')
plt.legend()

plt.show()

# %% [markdown]
# #### 3)SGA

# %% [markdown]
# We now train the SG algorithm with $\eta=0.2$ and $\gamma=1$

# %%
initial_x = 0.5
initial_y = 0.5
max_iters = 50
gamma = 1
eta = 0.2
objectives_SG, xs_SG, ys_SG = SG_xy(initial_x, initial_y, alpha, max_iters, eta, gamma)
# Out:
# SG(0/49): objective=0.25
# SG(1/49): objective=-0.009999999999999995
# SG(2/49): objective=0.0003999999999999996
# SG(3/49): objective=-1.5999999999999972e-05
# SG(4/49): objective=6.399999999999992e-07
# SG(5/49): objective=-2.559999999999996e-08
# SG(6/49): objective=1.0239999999999977e-09
# SG(7/49): objective=-4.095999999999991e-11
# SG(8/49): objective=1.6383999999999957e-12
# SG(9/49): objective=-6.553599999999982e-14
# SG(10/49): objective=2.621439999999994e-15
# SG(11/49): objective=-1.0485759999999982e-16
# SG(12/49): objective=4.194303999999991e-18
# SG(13/49): objective=-1.677721599999996e-19
# SG(14/49): objective=6.710886399999981e-21
# SG(15/49): objective=-2.6843545599999918e-22
# SG(16/49): objective=1.0737418239999973e-23
# SG(17/49): objective=-4.294967295999991e-25
# SG(18/49): objective=1.7179869183999976e-26
# SG(19/49): objective=-6.8719476735999935e-28
# SG(20/49): objective=2.748779069439997e-29
# SG(21/49): objective=-1.0995116277759986e-30
# SG(22/49): objective=4.3980465111039943e-32
# SG(23/49): objective=-1.7592186044415983e-33
# SG(24/49): objective=7.036874417766397e-35
# SG(25/49): objective=-2.8147497671065584e-36
# SG(26/49): objective=1.1258999068426228e-37
# SG(27/49): objective=-4.5035996273704896e-39
# SG(28/49): objective=1.8014398509481954e-40
# SG(29/49): objective=-7.205759403792782e-42
# SG(30/49): objective=2.8823037615171118e-43
# SG(31/49): objective=-1.152921504606844e-44
# SG(32/49): objective=4.611686018427377e-46
# SG(33/49): objective=-1.8446744073709515e-47
# SG(34/49): objective=7.37869762948381e-49
# SG(35/49): objective=-2.9514790517935244e-50
# SG(36/49): objective=1.1805916207174096e-51
# SG(37/49): objective=-4.722366482869636e-53
# SG(38/49): objective=1.888946593147854e-54
# SG(39/49): objective=-7.555786372591414e-56
# SG(40/49): objective=3.022314549036565e-57
# SG(41/49): objective=-1.2089258196146258e-58
# SG(42/49): objective=4.8357032784585064e-60
# SG(43/49): objective=-1.9342813113834017e-61
# SG(44/49): objective=7.737125245533605e-63
# SG(45/49): objective=-3.094850098213444e-64
# SG(46/49): objective=1.2379400392853769e-65
# SG(47/49): objective=-4.951760157141509e-67
# SG(48/49): objective=1.9807040628566045e-68
# SG(49/49): objective=-7.922816251426418e-70

# %%
plt.figure()
plt.grid()
plt.plot(xs_SG, ys_SG, 'b--', linewidth=1, label="SG")
plt.ylabel("y")
plt.xlabel("x")
plt.title("Trajectory of SG")
plt.legend()
# Add markers for the starting and end points
plt.scatter(xs_SG[0], ys_SG[0], c='r', marker='o', label='Start')
plt.scatter(xs_SG[-1], ys_SG[-1], c='g', marker='o', label='End')
plt.legend()

plt.show()

# %% [markdown]
# #### 4) ConOpt

# %% [markdown]
# In the linear case ($f(x,y)=xy$), ConOpt is the same SG because the second derivatives wrt the same variable are equals to zero.

# %% [markdown]
# #### 5) OGDA

# %% [markdown]
# Similarly to ConOpt, OGDA is the same as LCGD in the linear case for the same reason.

# %% [markdown]
# #### 5) CGD

# %%
initial_x = 0.5
initial_y = 0.5
max_iters = 50
eta = 0.2
objectives_CGD, xs_CGD, ys_CGD = CGD_xy(initial_x, initial_y, alpha, max_iters, eta)
# Out:
# Competitive Gradient Descent(0/49): objective=0.25
# Competitive Gradient Descent(1/49): objective=0.22189349112426032
# Competitive Gradient Descent(2/49): objective=0.1627547179720598
# Competitive Gradient Descent(3/49): objective=0.08376069469498378
# Competitive Gradient Descent(4/49): objective=-0.0017882619801136554
# Competitive Gradient Descent(5/49): objective=-0.0806159002374279
# Competitive Gradient Descent(6/49): objective=-0.1414517996262462
# Competitive Gradient Descent(7/49): objective=-0.17656393772648377
# Competitive Gradient Descent(8/49): objective=-0.18264696820321988
# Competitive Gradient Descent(9/49): objective=-0.16098210172309393
# Competitive Gradient Descent(10/49): objective=-0.11689965523772233
# Competitive Gradient Descent(11/49): objective=-0.0586771785626229
# Competitive Gradient Descent(12/49): objective=0.003919630545013261
# Competitive Gradient Descent(13/49): objective=0.061208274046827264
# Competitive Gradient Descent(14/49): objective=0.10502982213840152
# Competitive Gradient Descent(15/49): objective=0.129852981193513
# Competitive Gradient Descent(16/49): objective=0.13340227602916369
# Competitive Gradient Descent(17/49): objective=0.11675239347492719
# Competitive Gradient Descent(18/49): objective=0.08391486634864695
# Competitive Gradient Descent(19/49): objective=0.041017150438678755
# Competitive Gradient Descent(20/49): objective=-0.004772501392736439
# Competitive Gradient Descent(21/49): objective=-0.0463945572418017
# Competitive Gradient Descent(22/49): objective=-0.07794475639009137
# Competitive Gradient Descent(23/49): objective=-0.09546909673370352
# Competitive Gradient Descent(24/49): objective=-0.09740746055715549
# Competitive Gradient Descent(25/49): objective=-0.08464610534026906
# Competitive Gradient Descent(26/49): objective=-0.060200685739793924
# Competitive Gradient Descent(27/49): objective=-0.02860504001491798
# Competitive Gradient Descent(28/49): objective=0.00488074048738111
# Competitive Gradient Descent(29/49): objective=0.035111003837545965
# Competitive Gradient Descent(30/49): objective=0.05781470680538753
# Competitive Gradient Descent(31/49): objective=0.07016756030769053
# Competitive Gradient Descent(32/49): objective=0.07110485298204354
# Competitive Gradient Descent(33/49): objective=0.061347778677730266
# Competitive Gradient Descent(34/49): objective=0.043160948667898096
# Competitive Gradient Descent(35/49): objective=0.01989759870990576
# Competitive Gradient Descent(36/49): objective=-0.00458354210880089
# Competitive Gradient Descent(37/49): objective=-0.026532913793272436
# Competitive Gradient Descent(38/49): objective=-0.04286210463598575
# Competitive Gradient Descent(39/49): objective=-0.051555405979863356
# Competitive Gradient Descent(40/49): objective=-0.051890047009385994
# Competitive Gradient Descent(41/49): objective=-0.04444663857078194
# Competitive Gradient Descent(42/49): objective=-0.03092409305336107
# Competitive Gradient Descent(43/49): objective=-0.013801423901323325
# Competitive Gradient Descent(44/49): objective=0.004091493308820523
# Competitive Gradient Descent(45/49): objective=0.020023198090106078
# Competitive Gradient Descent(46/49): objective=0.03176132306229951
# Competitive Gradient Descent(47/49): objective=0.03786847465746022
# Competitive Gradient Descent(48/49): objective=0.03785701579144241
# Competitive Gradient Descent(49/49): objective=0.03219026965801517

# %%
plt.figure()
plt.grid()
plt.plot(xs_CGD, ys_CGD, 'b--', linewidth=1, label="CGD")
plt.ylabel("y")
plt.xlabel("x")
plt.title("Trajectory of CGD")
plt.legend()
# Add markers for the starting and end points
plt.scatter(xs_CGD[0], ys_CGD[0], c='r', marker='o', label='Start')
plt.scatter(xs_CGD[-1], ys_CGD[-1], c='g', marker='o', label='End')
plt.legend()

plt.show()

# %% [markdown]
# #### Plotting together

# %% [markdown]
# Now we want to compare the trajectories of these different 4 algorithms by plotting them in the same plot:

# %%
plt.figure()
plt.grid()
plt.plot(xs_LCGD, ys_LCGD, 'b-.', linewidth=1, label="LCGD")
plt.plot(xs_GD, ys_GD, 'y-*', linewidth=1, label="GD")
plt.plot(xs_SG, ys_SG, 'r--', linewidth=1, label="SG")
plt.plot(xs_CGD, ys_CGD, 'g-', linewidth=1, label="CGD")
plt.ylabel("y")
plt.xlabel("x")
plt.title("Trajectories")
plt.legend()

# Add markers for the starting and end points
starts_x = [xs_LCGD[0], xs_GD[0], xs_CGD[0], xs_SG[0]]
starts_y = [ys_LCGD[0], ys_GD[0], ys_CGD[0], ys_SG[0]]
ends_x = [xs_LCGD[-1], xs_GD[-1], xs_CGD[-1], xs_SG[-1]]
ends_y = [ys_LCGD[-1], ys_GD[-1], ys_CGD[-1], ys_SG[-1]]

plt.scatter(starts_x, starts_y, c='r', marker='o', label='Start')
plt.scatter(ends_x, ends_y, c='g', marker='o', label='End')
plt.legend()

plt.show()
