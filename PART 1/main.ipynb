# %% [markdown]
# # **SECTION 1**

# %% [markdown]
# In this part, we propose three simple examples showing how changing the optimization algorithm, then it changes the convergence of the optimization problem $min_{x\in\mathbb{R^m}}f(x,y)$, $min_{y\in\mathbb{R^m}}g(x,y)$. Many problems in competitive optimization
# (including GANs) have the form $f(x,y)=\mathbb{\phi}(\mathcal{G}(x),\mathcal{D}(y))$, $f(x,y)=\mathbb{\theta}(\mathcal{G}(x),\mathcal{D}(y))$. We will explore different modifications of Gradient Descent that take into account some additional terms. These new terms refer in some way to competition, consensus and equilibrium (we will describe them further in this section).

# %% [markdown]
# ## **Problem  1**
# We firstly consider the problem $$min_{x\in\mathbb{R^m}}f(x,y)$$  $$min_{y\in\mathbb{R^m}}(-f(x,y))$$
# In this first case, we take $f(x,y)= \alpha xy$

# %% [markdown]
# Choose $\alpha \in \{ 1.0, 3.0, 6.0 \}$

# %%
# Importing libraries
 
import numpy as np
from optimizers.optimizers_xy import *
from optimizers.optimizers_conv_conc import *
from optimizers.optimizers_conc_conv import *
from plots import *

# %%
alpha = 1           # Choose alpha in (1.0, 3.0, 6.0)
Xinit = 0.5
Yinit = 0.5
max_iters = 50
eta = 0.2
gamma = 1
optimizers=['GDA','LCGD','SGA','CGD', 'OGDA']

# %% [markdown]
# #### 1. **Gradient Descent Ascent** (GDA)

# %%
objectives_GDA, xs_GDA, ys_GDA = GDA_alphaxy(Xinit, Yinit, alpha, max_iters, eta)
# Out:
# Gradient Descent Ascent (GDA) (0/49): objective=0.25
# Gradient Descent Ascent (GDA) (1/49): objective=0.24
# Gradient Descent Ascent (GDA) (2/49): objective=0.1904
# Gradient Descent Ascent (GDA) (3/49): objective=0.10598400000000004
# Gradient Descent Ascent (GDA) (4/49): objective=-0.002447359999999964
# Gradient Descent Ascent (GDA) (5/49): objective=-0.11933122559999998
# Gradient Descent Ascent (GDA) (6/49): objective=-0.226468888576
# Gradient Descent Ascent (GDA) (7/49): objective=-0.30575161245696003
# Gradient Descent Ascent (GDA) (8/49): objective=-0.3420943460335616
# Gradient Descent Ascent (GDA) (9/49): objective=-0.3261202003509903
# Gradient Descent Ascent (GDA) (10/49): objective=-0.2561415400040012
# Gradient Descent Ascent (GDA) (11/49): objective=-0.13906014810805115
# Gradient Descent Ascent (GDA) (12/49): objective=0.010047205300869477
# Gradient Descent Ascent (GDA) (13/49): objective=0.1696980903713375
# Gradient Descent Ascent (GDA) (14/49): objective=0.3149532762595476
# Gradient Descent Ascent (GDA) (15/49): objective=0.42116483587269277
# Gradient Descent Ascent (GDA) (16/49): objective=0.46798302127324337
# Gradient Descent Ascent (GDA) (17/49): objective=0.4429955143647228
# Gradient Descent Ascent (GDA) (18/49): objective=0.3443809517711277
# Gradient Descent Ascent (GDA) (19/49): objective=0.18206747906368104
# Gradient Descent Ascent (GDA) (20/49): objective=-0.022912877633384163
# Gradient Descent Ascent (GDA) (21/49): objective=-0.24091691041137503
# Gradient Descent Ascent (GDA) (22/49): objective=-0.43777789954157176
# Gradient Descent Ascent (GDA) (23/49): objective=-0.5799578368188746
# Gradient Descent Ascent (GDA) (24/49): objective=-0.6400184705480751
# Gradient Descent Ascent (GDA) (25/49): objective=-0.6015530671490096
# Gradient Descent Ascent (GDA) (26/49): objective=-0.46273791118130025
# Gradient Descent Ascent (GDA) (27/49): objective=-0.23781699203972778
# Gradient Descent Ascent (GDA) (28/49): objective=0.04388870001741707
# Gradient Descent Ascent (GDA) (29/49): objective=0.3414891626236104
# Gradient Descent Ascent (GDA) (30/49): objective=0.6081891742984936
# Gradient Descent Ascent (GDA) (31/49): objective=0.7983685363594107
# Gradient Descent Ascent (GDA) (32/49): objective=0.875050178888818
# Gradient Descent Ascent (GDA) (33/49): objective=0.8165809345401916
# Gradient Descent Ascent (GDA) (34/49): objective=0.6213811208310226
# Gradient Descent Ascent (GDA) (35/49): objective=0.3098378131968921
# Gradient Descent Ascent (GDA) (36/49): objective=-0.07719721895280111
# Gradient Descent Ascent (GDA) (37/49): objective=-0.48333923914313665
# Gradient Descent Ascent (GDA) (38/49): objective=-0.8445148271354725
# Gradient Descent Ascent (GDA) (39/49): objective=-1.0986887470428908
# Gradient Descent Ascent (GDA) (40/49): objective=-1.196055157292623
# Gradient Descent Ascent (GDA) (41/49): objective=-1.1080841532002457
# Gradient Descent Ascent (GDA) (42/49): objective=-0.8338683160167705
# Gradient Descent Ascent (GDA) (43/49): objective=-0.4025233466508136
# Gradient Descent Ascent (GDA) (44/49): objective=0.1290671450341769
# Gradient Descent Ascent (GDA) (45/49): objective=0.6831781702031396
# Gradient Descent Ascent (GDA) (46/49): objective=1.1721030627210622
# Gradient Descent Ascent (GDA) (47/49): objective=1.5115123715327237
# Gradient Descent Ascent (GDA) (48/49): objective=1.6343570807037284
# Gradient Descent Ascent (GDA) (49/49): objective=1.5031138139013647

# %%
plot_trajectory(xs_GDA, ys_GDA, "GD")

# %% [markdown]
# GD fails to converge in this problem.

# %% [markdown]
# #### 2. **Linearized Competitive Gradient Descent** (LCGD)

# %%
objectives_LCGD, xs_LCGD, ys_LCGD = LCGD_alphaxy(Xinit, Yinit, alpha, max_iters, eta)
# Out:
# Linearized Competitive Gradient Descent (LCDG) (0/49): objective=0.25
# Linearized Competitive Gradient Descent (LCDG) (1/49): objective=0.22040000000000004
# Linearized Competitive Gradient Descent (LCDG) (2/49): objective=0.15744064
# Linearized Competitive Gradient Descent (LCDG) (3/49): objective=0.07380106342399997
# Linearized Competitive Gradient Descent (LCDG) (4/49): objective=-0.015455319488921638
# Linearized Competitive Gradient Descent (LCDG) (5/49): objective=-0.09549278517198591
# Linearized Competitive Gradient Descent (LCDG) (6/49): objective=-0.1540817380671675
# Linearized Competitive Gradient Descent (LCDG) (7/49): objective=-0.18337717144794916
# Linearized Competitive Gradient Descent (LCDG) (8/49): objective=-0.18085516534573062
# Linearized Competitive Gradient Descent (LCDG) (9/49): objective=-0.1493196222149152
# Linearized Competitive Gradient Descent (LCDG) (10/49): objective=-0.09604818744954784
# Linearized Competitive Gradient Descent (LCDG) (11/49): objective=-0.031280108140099794
# Linearized Competitive Gradient Descent (LCDG) (12/49): objective=0.033660228796084234
# Linearized Competitive Gradient Descent (LCDG) (13/49): objective=0.08827363564445491
# Linearized Competitive Gradient Descent (LCDG) (14/49): objective=0.12451931711678436
# Linearized Competitive Gradient Descent (LCDG) (15/49): objective=0.13792807474117755
# Linearized Competitive Gradient Descent (LCDG) (16/49): objective=0.12805493661718118
# Linearized Competitive Gradient Descent (LCDG) (17/49): objective=0.09824788242046839
# Linearized Competitive Gradient Descent (LCDG) (18/49): objective=0.054821524111449985
# Linearized Competitive Gradient Descent (LCDG) (19/49): objective=0.005813993865230269
# Linearized Competitive Gradient Descent (LCDG) (20/49): objective=-0.0404408347031104
# Linearized Competitive Gradient Descent (LCDG) (21/49): objective=-0.07668133196769875
# Linearized Competitive Gradient Descent (LCDG) (22/49): objective=-0.09780991349031508
# Linearized Competitive Gradient Descent (LCDG) (23/49): objective=-0.10155316256867779
# Linearized Competitive Gradient Descent (LCDG) (24/49): objective=-0.08861619752079751
# Linearized Competitive Gradient Descent (LCDG) (25/49): objective=-0.06234445355386956
# Linearized Competitive Gradient Descent (LCDG) (26/49): objective=-0.027984597054766285
# Linearized Competitive Gradient Descent (LCDG) (27/49): objective=0.008305888631400865
# Linearized Competitive Gradient Descent (LCDG) (28/49): objective=0.040521587803279316
# Linearized Competitive Gradient Descent (LCDG) (29/49): objective=0.06376741969909248
# Linearized Competitive Gradient Descent (LCDG) (30/49): objective=0.0749654330409412
# Linearized Competitive Gradient Descent (LCDG) (31/49): objective=0.07321494078519386
# Linearized Competitive Gradient Descent (LCDG) (32/49): objective=0.05977395478011204
# Linearized Competitive Gradient Descent (LCDG) (33/49): objective=0.03769344391231835
# Linearized Competitive Gradient Descent (LCDG) (34/49): objective=0.011189624970439727
# Linearized Competitive Gradient Descent (LCDG) (35/49): objective=-0.015124621916628321
# Linearized Competitive Gradient Descent (LCDG) (36/49): objective=-0.037014494909505424
# Linearized Competitive Gradient Descent (LCDG) (37/49): objective=-0.051278604308515316
# Linearized Competitive Gradient Descent (LCDG) (38/49): objective=-0.056188073322705034
# Linearized Competitive Gradient Descent (LCDG) (39/49): objective=-0.051654790006203016
# Linearized Competitive Gradient Descent (LCDG) (40/49): objective=-0.03912204376201713
# Linearized Competitive Gradient Descent (LCDG) (41/49): objective=-0.021216117340310443
# Linearized Competitive Gradient Descent (LCDG) (42/49): objective=-0.0012330994924914295
# Linearized Competitive Gradient Descent (LCDG) (43/49): objective=0.01744380294139904
# Linearized Competitive Gradient Descent (LCDG) (44/49): objective=0.03189712907693053
# Linearized Competitive Gradient Descent (LCDG) (45/49): objective=0.040111177178879034
# Linearized Competitive Gradient Descent (LCDG) (46/49): objective=0.04122956380732557
# Linearized Competitive Gradient Descent (LCDG) (47/49): objective=0.03560618179611444
# Linearized Competitive Gradient Descent (LCDG) (48/49): objective=0.02465689097037828
# Linearized Competitive Gradient Descent (LCDG) (49/49): objective=0.010550899673368858

# %%
plot_trajectory(xs_LCGD, ys_LCGD, "LCGD")

# %% [markdown]
# #### 3. **Symplectic Gradient Adjustmen** (SGA)

# %% [markdown]
# We now train the SGA algorithm with $\eta=0.2$ and $\gamma=1$

# %%
objectives_SGA, xs_SGA, ys_SGA = SGA_alphaxy(Xinit, Yinit, alpha, max_iters, eta, gamma)
# Out:
# Symplectic Gradient Adjustment (SGA) (0/49): objective=0.25
# Symplectic Gradient Adjustment (SGA) (1/49): objective=0.15
# Symplectic Gradient Adjustment (SGA) (2/49): objective=0.06439999999999997
# Symplectic Gradient Adjustment (SGA) (3/49): objective=0.00791999999999999
# Symplectic Gradient Adjustment (SGA) (4/49): objective=-0.020274560000000004
# Symplectic Gradient Adjustment (SGA) (5/49): objective=-0.02799168
# Symplectic Gradient Adjustment (SGA) (6/49): objective=-0.024215059455999995
# Symplectic Gradient Adjustment (SGA) (7/49): objective=-0.016114718515199994
# Symplectic Gradient Adjustment (SGA) (8/49): objective=-0.008140618725785595
# Symplectic Gradient Adjustment (SGA) (9/49): objective=-0.0023172966295142363
# Symplectic Gradient Adjustment (SGA) (10/49): objective=0.000983466143386175
# Symplectic Gradient Adjustment (SGA) (11/49): objective=0.002251677333550793
# Symplectic Gradient Adjustment (SGA) (12/49): objective=0.002247258055559184
# Symplectic Gradient Adjustment (SGA) (13/49): objective=0.0016555340676371341
# Symplectic Gradient Adjustment (SGA) (14/49): objective=0.0009475087562739943
# Symplectic Gradient Adjustment (SGA) (15/49): objective=0.00037149155465338236
# Symplectic Gradient Adjustment (SGA) (16/49): objective=7.661816682963875e-06
# Symplectic Gradient Adjustment (SGA) (17/49): objective=-0.00016258351485216733
# Symplectic Gradient Adjustment (SGA) (18/49): objective=-0.00019864304185680326
# Symplectic Gradient Adjustment (SGA) (19/49): objective=-0.00016319303296052177
# Symplectic Gradient Adjustment (SGA) (20/49): objective=-0.00010397909699804027
# Symplectic Gradient Adjustment (SGA) (21/49): objective=-4.931445795670305e-05
# Symplectic Gradient Adjustment (SGA) (22/49): objective=-1.1097415096149845e-05
# Symplectic Gradient Adjustment (SGA) (23/49): objective=9.486107243799677e-06
# Symplectic Gradient Adjustment (SGA) (24/49): objective=1.6514773433019305e-05
# Symplectic Gradient Adjustment (SGA) (25/49): objective=1.543135213009019e-05
# Symplectic Gradient Adjustment (SGA) (26/49): objective=1.0881191320680105e-05
# Symplectic Gradient Adjustment (SGA) (27/49): objective=5.92197235986242e-06
# Symplectic Gradient Adjustment (SGA) (28/49): objective=2.0749039651524233e-06
# Symplectic Gradient Adjustment (SGA) (29/49): objective=-2.4843526101747517e-07
# Symplectic Gradient Adjustment (SGA) (30/49): objective=-1.2575579067074508e-06
# Symplectic Gradient Adjustment (SGA) (31/49): objective=-1.3941930233544603e-06
# Symplectic Gradient Adjustment (SGA) (32/49): objective=-1.0915368519638271e-06
# Symplectic Gradient Adjustment (SGA) (33/49): objective=-6.651693683574902e-07
# Symplectic Gradient Adjustment (SGA) (34/49): objective=-2.9347660168091455e-07
# Symplectic Gradient Adjustment (SGA) (35/49): objective=-4.459760608859397e-08
# Symplectic Gradient Adjustment (SGA) (36/49): objective=8.21864533109421e-08
# Symplectic Gradient Adjustment (SGA) (37/49): objective=1.1924567702849636e-07
# Symplectic Gradient Adjustment (SGA) (38/49): objective=1.0509179642321598e-07
# Symplectic Gradient Adjustment (SGA) (39/49): objective=7.097095464988245e-08
# Symplectic Gradient Adjustment (SGA) (40/49): objective=3.657069891376388e-08
# Symplectic Gradient Adjustment (SGA) (41/49): objective=1.1067869266411014e-08
# Symplectic Gradient Adjustment (SGA) (42/49): objective=-3.6288480580311984e-09
# Symplectic Gradient Adjustment (SGA) (43/49): objective=-9.472400418425892e-09
# Symplectic Gradient Adjustment (SGA) (44/49): objective=-9.688901160077444e-09
# Symplectic Gradient Adjustment (SGA) (45/49): objective=-7.246643438612801e-09
# Symplectic Gradient Adjustment (SGA) (46/49): objective=-4.215824229915551e-09
# Symplectic Gradient Adjustment (SGA) (47/49): objective=-1.7081411498841017e-09
# Symplectic Gradient Adjustment (SGA) (48/49): objective=-1.003722559479714e-10
# Symplectic Gradient Adjustment (SGA) (49/49): objective=6.693977605688428e-10

# %%
plot_trajectory(xs_SGA, ys_SGA, "SGA")

# %% [markdown]
# #### 4. **Optimistic Gradient Descent Ascent** (OGDA)

# %%
objectives_OGDA, xs_OGDA, ys_OGDA = OGDA_alphaxy(Xinit, Yinit, alpha, max_iters, eta)
# Out:
# Optimistic Gradient Descent Ascent (OGDA) (0/49): objective=0.25
# Optimistic Gradient Descent Ascent (OGDA) (1/49): objective=0.21
# Optimistic Gradient Descent Ascent (OGDA) (2/49): objective=0.08639999999999999
# Optimistic Gradient Descent Ascent (OGDA) (3/49): objective=-0.019823999999999998
# Optimistic Gradient Descent Ascent (OGDA) (4/49): objective=-0.11249215999999998
# Optimistic Gradient Descent Ascent (OGDA) (5/49): objective=-0.18022717439999997
# Optimistic Gradient Descent Ascent (OGDA) (6/49): objective=-0.213341879296
# Optimistic Gradient Descent Ascent (OGDA) (7/49): objective=-0.20920981745664
# Optimistic Gradient Descent Ascent (OGDA) (8/49): objective=-0.1715747393765376
# Optimistic Gradient Descent Ascent (OGDA) (9/49): objective=-0.10926646699091558
# Optimistic Gradient Descent Ascent (OGDA) (10/49): objective=-0.03437850735057043
# Optimistic Gradient Descent Ascent (OGDA) (11/49): objective=0.03994844532113893
# Optimistic Gradient Descent Ascent (OGDA) (12/49): objective=0.10173837787091351
# Optimistic Gradient Descent Ascent (OGDA) (13/49): objective=0.14202203649967177
# Optimistic Gradient Descent Ascent (OGDA) (14/49): objective=0.1560418214225593
# Optimistic Gradient Descent Ascent (OGDA) (15/49): objective=0.14367701167913102
# Optimistic Gradient Descent Ascent (OGDA) (16/49): objective=0.10908426246711336
# Optimistic Gradient Descent Ascent (OGDA) (17/49): objective=0.05967565490887714
# Optimistic Gradient Descent Ascent (OGDA) (18/49): objective=0.004653741553111344
# Optimistic Gradient Descent Ascent (OGDA) (19/49): objective=-0.04662325434355334
# Optimistic Gradient Descent Ascent (OGDA) (20/49): objective=-0.08616778549109685
# Optimistic Gradient Descent Ascent (OGDA) (21/49): objective=-0.1085428634929749
# Optimistic Gradient Descent Ascent (OGDA) (22/49): objective=-0.11153296168099115
# Optimistic Gradient Descent Ascent (OGDA) (23/49): objective=-0.09623902967203249
# Optimistic Gradient Descent Ascent (OGDA) (24/49): objective=-0.06662932626891423
# Optimistic Gradient Descent Ascent (OGDA) (25/49): objective=-0.028663202814875815
# Optimistic Gradient Descent Ascent (OGDA) (26/49): objective=0.010835533520517807
# Optimistic Gradient Descent Ascent (OGDA) (27/49): objective=0.04535298161858265
# Optimistic Gradient Descent Ascent (OGDA) (28/49): objective=0.06971338813668998
# Optimistic Gradient Descent Ascent (OGDA) (29/49): objective=0.08080690298200563
# Optimistic Gradient Descent Ascent (OGDA) (30/49): objective=0.07792370207118424
# Optimistic Gradient Descent Ascent (OGDA) (31/49): objective=0.0626726120435506
# Optimistic Gradient Descent Ascent (OGDA) (32/49): objective=0.038531362584633175
# Optimistic Gradient Descent Ascent (OGDA) (33/49): objective=0.010131321296815599
# Optimistic Gradient Descent Ascent (OGDA) (34/49): objective=-0.01758589612047811
# Optimistic Gradient Descent Ascent (OGDA) (35/49): objective=-0.04019305523813859
# Optimistic Gradient Descent Ascent (OGDA) (36/49): objective=-0.054451327779106655
# Optimistic Gradient Descent Ascent (OGDA) (37/49): objective=-0.05873700436859627
# Optimistic Gradient Descent Ascent (OGDA) (38/49): objective=-0.05317209349017988
# Optimistic Gradient Descent Ascent (OGDA) (39/49): objective=-0.03946188831639597
# Optimistic Gradient Descent Ascent (OGDA) (40/49): objective=-0.02048972690764368
# Optimistic Gradient Descent Ascent (OGDA) (41/49): objective=0.00024566214604914577
# Optimistic Gradient Descent Ascent (OGDA) (42/49): objective=0.019246356108453534
# Optimistic Gradient Descent Ascent (OGDA) (43/49): objective=0.03358093474976561
# Optimistic Gradient Descent Ascent (OGDA) (44/49): objective=0.041312308087642864
# Optimistic Gradient Descent Ascent (OGDA) (45/49): objective=0.04172974705790238
# Optimistic Gradient Descent Ascent (OGDA) (46/49): objective=0.035363592838666
# Optimistic Gradient Descent Ascent (OGDA) (47/49): objective=0.02379803008118154
# Optimistic Gradient Descent Ascent (OGDA) (48/49): objective=0.00932871330709771
# Optimistic Gradient Descent Ascent (OGDA) (49/49): objective=-0.00546669510990306

# %%
plot_trajectory(xs_OGDA, ys_OGDA, "OGDA")

# %% [markdown]
# #### 5. **Competitive Gradient Descent** (CGD)

# %%
objectives_CGD, xs_CGD, ys_CGD = CGD_alphaxy(Xinit, Yinit, alpha, max_iters, eta)
# Out:
# Competitive Gradient Descent (CGD) (0/49): objective=0.25
# Competitive Gradient Descent (CGD) (1/49): objective=0.22189349112426035
# Competitive Gradient Descent (CGD) (2/49): objective=0.16275471797205981
# Competitive Gradient Descent (CGD) (3/49): objective=0.08376069469498383
# Competitive Gradient Descent (CGD) (4/49): objective=-0.001788261980113601
# Competitive Gradient Descent (CGD) (5/49): objective=-0.08061590023742783
# Competitive Gradient Descent (CGD) (6/49): objective=-0.14145179962624616
# Competitive Gradient Descent (CGD) (7/49): objective=-0.1765639377264837
# Competitive Gradient Descent (CGD) (8/49): objective=-0.18264696820321982
# Competitive Gradient Descent (CGD) (9/49): objective=-0.16098210172309393
# Competitive Gradient Descent (CGD) (10/49): objective=-0.11689965523772236
# Competitive Gradient Descent (CGD) (11/49): objective=-0.058677178562622986
# Competitive Gradient Descent (CGD) (12/49): objective=0.003919630545013169
# Competitive Gradient Descent (CGD) (13/49): objective=0.06120827404682717
# Competitive Gradient Descent (CGD) (14/49): objective=0.10502982213840144
# Competitive Gradient Descent (CGD) (15/49): objective=0.12985298119351293
# Competitive Gradient Descent (CGD) (16/49): objective=0.13340227602916366
# Competitive Gradient Descent (CGD) (17/49): objective=0.11675239347492722
# Competitive Gradient Descent (CGD) (18/49): objective=0.083914866348647
# Competitive Gradient Descent (CGD) (19/49): objective=0.04101715043867886
# Competitive Gradient Descent (CGD) (20/49): objective=-0.004772501392736319
# Competitive Gradient Descent (CGD) (21/49): objective=-0.04639455724180158
# Competitive Gradient Descent (CGD) (22/49): objective=-0.07794475639009125
# Competitive Gradient Descent (CGD) (23/49): objective=-0.09546909673370343
# Competitive Gradient Descent (CGD) (24/49): objective=-0.09740746055715546
# Competitive Gradient Descent (CGD) (25/49): objective=-0.08464610534026909
# Competitive Gradient Descent (CGD) (26/49): objective=-0.060200685739794015
# Competitive Gradient Descent (CGD) (27/49): objective=-0.028605040014918096
# Competitive Gradient Descent (CGD) (28/49): objective=0.004880740487380974
# Competitive Gradient Descent (CGD) (29/49): objective=0.035111003837545826
# Competitive Gradient Descent (CGD) (30/49): objective=0.05781470680538741
# Competitive Gradient Descent (CGD) (31/49): objective=0.07016756030769046
# Competitive Gradient Descent (CGD) (32/49): objective=0.07110485298204351
# Competitive Gradient Descent (CGD) (33/49): objective=0.06134777867773031
# Competitive Gradient Descent (CGD) (34/49): objective=0.04316094866789819
# Competitive Gradient Descent (CGD) (35/49): objective=0.019897598709905893
# Competitive Gradient Descent (CGD) (36/49): objective=-0.004583542108800734
# Competitive Gradient Descent (CGD) (37/49): objective=-0.026532913793272293
# Competitive Gradient Descent (CGD) (38/49): objective=-0.04286210463598564
# Competitive Gradient Descent (CGD) (39/49): objective=-0.051555405979863286
# Competitive Gradient Descent (CGD) (40/49): objective=-0.05189004700938599
# Competitive Gradient Descent (CGD) (41/49): objective=-0.04444663857078199
# Competitive Gradient Descent (CGD) (42/49): objective=-0.030924093053361166
# Competitive Gradient Descent (CGD) (43/49): objective=-0.013801423901323457
# Competitive Gradient Descent (CGD) (44/49): objective=0.004091493308820387
# Competitive Gradient Descent (CGD) (45/49): objective=0.02002319809010595
# Competitive Gradient Descent (CGD) (46/49): objective=0.03176132306229941
# Competitive Gradient Descent (CGD) (47/49): objective=0.03786847465746016
# Competitive Gradient Descent (CGD) (48/49): objective=0.037857015791442405
# Competitive Gradient Descent (CGD) (49/49): objective=0.03219026965801522

# %%
plot_trajectory(xs_CGD, ys_CGD, "CGD")

# %% [markdown]
# #### **Plotting together**

# %% [markdown]
# Now we want to compare the trajectories of these different 5 algorithms by plotting them in the same plot:

# %%
xs_list = [xs_GDA, xs_LCGD, xs_SGA, xs_CGD, xs_OGDA]
ys_list = [ys_GDA, ys_LCGD, ys_SGA, ys_CGD, ys_OGDA]
line_styles = ['y-*', 'b-.', 'r--', 'g-', 'c-']

plot_trajectories(optimizers, xs_list, ys_list, line_styles)

# %% [markdown]
# ## **Problem  2**
# In this case, we take $f(x,y)= \alpha(x^2-y^2)$, i.e. convex-concave problem.

# %%
import optimizers.optimizers_conv_conc as v_c
Xinit=0.5
Yinit=0.5
eta=0.2
gamma=1
optimizers=['GDA','LCGD','SGA','ConOpt','OGDA','CGD']

# %% [markdown]
# Choose $\alpha \in \{ 1.0, 3.0, 6.0 \}$

# %% [markdown]
# the case where $\alpha = 1.0$

# %%
alpha=1
records={}
for optimizer in optimizers:
    record=v_c.run(alpha,eta,gamma,Xinit,Yinit,optimizer=optimizer)
    records[optimizer]=record

step=[i*25 for i in range(5)]
for optimizer in optimizers:
    plt.plot(step,records[optimizer],label=optimizer)
plt.legend(title='optimizers:')
plt.xlabel('iteration')
plt.ylabel('log10(||(x,y)||)')
plt.show()

# %% [markdown]
# the case where $\alpha = 3.0$

# %%
alpha=3
records={}
for optimizer in optimizers:
    record=v_c.run(alpha,eta,gamma,Xinit,Yinit,optimizer=optimizer)
    records[optimizer]=record

step=[i*25 for i in range(5)]
for optimizer in optimizers:
    plt.plot(step,records[optimizer],label=optimizer)
plt.legend(title='Optimizers:')
plt.xlabel('iteration')
plt.ylabel('log10(||(x,y)||)')
plt.show()

# %% [markdown]
# the case where $\alpha = 6.0$

# %%
alpha=6
records={}
for optimizer in optimizers:
    record=v_c.run(alpha,eta,gamma,Xinit,Yinit,optimizer=optimizer)
    records[optimizer]=record

step=[i*25 for i in range(5)]
for optimizer in optimizers:
    plt.plot(step,records[optimizer],label=optimizer)
plt.legend(title='optimizers:')
plt.xlabel('iteration')
plt.ylabel('log10(||(x,y)||)')
plt.show()

# %% [markdown]
# ## **Problem  3**
# In this case, we take $f(x,y)= \alpha(-x^2+y^2)$, i.e. concave-convex problem

# %% [markdown]
# Choose $\alpha \in \{ 1.0, 3.0, 6.0 \}$

# %%
import optimizers.optimizers_conc_conv as c_v

# %% [markdown]
# the case where $\alpha = 1.0$

# %%
alpha=1
records={}
for optimizer in optimizers:
    record=c_v.run(alpha,eta,gamma,Xinit,Yinit,optimizer=optimizer)
    records[optimizer]=record

step=[i*25 for i in range(5)]
for optimizer in optimizers:
    plt.plot(step,records[optimizer],label=optimizer)
plt.legend(title='optimizers:')
plt.xlabel('iteration')
plt.ylabel('log10(||(x,y)||)')
plt.show()

# %% [markdown]
# the case where $\alpha = 3.0$

# %%
alpha=3
records={}
for optimizer in optimizers:
    record=c_v.run(alpha,eta,gamma,Xinit,Yinit,optimizer=optimizer)
    records[optimizer]=record

step=[i*25 for i in range(5)]
for optimizer in optimizers:
    plt.plot(step,records[optimizer],label=optimizer)
plt.legend(title='optimizers:')
plt.xlabel('iteration')
plt.ylabel('log10(||(x,y)||)')
plt.show()

# %% [markdown]
# the case where $\alpha = 6.0$

# %%
alpha=6
records={}
for optimizer in optimizers:
    record=c_v.run(alpha,eta,gamma,Xinit,Yinit,optimizer=optimizer)
    records[optimizer]=record

step=[i*25 for i in range(5)]
for optimizer in optimizers:
    plt.plot(step,records[optimizer],label=optimizer)
plt.legend(title='optimizers:')
plt.xlabel('iteration')
plt.ylabel('log10(||(x,y)||)')
plt.show()
